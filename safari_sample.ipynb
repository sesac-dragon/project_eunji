# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
res = requests.get(f'https://www.safaribookings.com/tours/page/1',
                   headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Whale/4.32.315.22 Safari/537.36',
                            'cookie': 'v=1.0.313; _ga=GA1.1.762332180.1752736610; CookieConsent={stamp:%27smOAvwHrouD3ERr0LAClV08CPzvUWzHxlHpL7bgMN48vygQuEMsBgw==%27%2Cnecessary:true%2Cpreferences:true%2Cstatistics:true%2Cmarketing:true%2Cmethod:%27explicit%27%2Cver:1%2Cutc:1752736611021%2Cregion:%27kr%27}; _gcl_au=1.1.1437524738.1752736611; _fbp=fb.1.1752736613392.535065786467195256; vsd=%7B%22cc%22%3A%22KR%22%2C%22cn%22%3A%22South%20Korea%22%2C%22ci%22%3A114%2C%22cp%22%3A%22%2B82%22%2C%22c%22%3A%22Asia%22%2C%22cg%22%3A0%2C%22ri%22%3A7%2C%22ip%22%3A%22211.34.202.232%22%2C%22d%22%3A2%2C%22cur%22%3A%22KRW%22%7D; laravel_session=rNYT1LO549F7Tu2fLIYwNovHOxQpTQrXlLfBgk5i; hpp=8%2C7%2C0; list_location=%2Ftours%3Fcur%3Dkrw%7C%7C%2Ftours%3Ffilter%3Dall%26cur%3Dkrw; _ga_D6DBBH8PKF=GS2.1.s1753160001$o11$g1$t1753161456$j59$l0$h0; _uetsid=b56e8e40662611f0b28a21bd6cad6003; _uetvid=02ee75c062de11f098f641fe3c03548d; prf=%7B%22sd%22%3A%22%22%2C%22sf%22%3A1%2C%22ta%22%3A2%2C%22tc%22%3A0%2C%22tca%22%3A%22%22%2C%22td%22%3Afalse%2C%22up%22%3A%2220250722141738%22%7D; XSRF-TOKEN=%3D'
                   })
soup = BeautifulSoup(res.text, 'html.parser')
total_count = int(soup.select_one('b.itemcount')['data-count'])
total_page = int(total_count/20)
total = 0
result= []
for page in range(1, 3):
    res = requests.get(f'https://www.safaribookings.com/tours/page/{page}',
                   headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Whale/4.32.315.22 Safari/537.36',
                            'cookie': 'v=1.0.313; _ga=GA1.1.762332180.1752736610; CookieConsent={stamp:%27smOAvwHrouD3ERr0LAClV08CPzvUWzHxlHpL7bgMN48vygQuEMsBgw==%27%2Cnecessary:true%2Cpreferences:true%2Cstatistics:true%2Cmarketing:true%2Cmethod:%27explicit%27%2Cver:1%2Cutc:1752736611021%2Cregion:%27kr%27}; _gcl_au=1.1.1437524738.1752736611; _fbp=fb.1.1752736613392.535065786467195256; vsd=%7B%22cc%22%3A%22KR%22%2C%22cn%22%3A%22South%20Korea%22%2C%22ci%22%3A114%2C%22cp%22%3A%22%2B82%22%2C%22c%22%3A%22Asia%22%2C%22cg%22%3A0%2C%22ri%22%3A7%2C%22ip%22%3A%22211.34.202.232%22%2C%22d%22%3A2%2C%22cur%22%3A%22KRW%22%7D; laravel_session=rNYT1LO549F7Tu2fLIYwNovHOxQpTQrXlLfBgk5i; hpp=8%2C7%2C0; list_location=%2Ftours%3Fcur%3Dkrw%7C%7C%2Ftours%3Ffilter%3Dall%26cur%3Dkrw; _ga_D6DBBH8PKF=GS2.1.s1753160001$o11$g1$t1753161456$j59$l0$h0; _uetsid=b56e8e40662611f0b28a21bd6cad6003; _uetvid=02ee75c062de11f098f641fe3c03548d; prf=%7B%22sd%22%3A%22%22%2C%22sf%22%3A1%2C%22ta%22%3A2%2C%22tc%22%3A0%2C%22tca%22%3A%22%22%2C%22td%22%3Afalse%2C%22up%22%3A%2220250722141738%22%7D; XSRF-TOKEN=%3D'
                   })
    soup = BeautifulSoup(res.text, 'html.parser')

    feeds = soup.select('li.col')

    total += len(feeds)

    print(f'현재 페이지: {page}')
    print(soup.title.text)
    print(f'{page}페이지 투어 개수: {len(feeds)}')
    print(f'누적 투어 개수: {total}')

    len(result)

    for feed in feeds:
        a_tag = feed.select_one('a.list__item')
        p_tag = feed.select_one('p.price b').text

        temp = {
        'Tour_ID':a_tag.attrs['data-id'],
        'Tour_title': a_tag.attrs['title'],
        'Tour_country': feed.select_one('p.desc b').text.strip(':'),
        'Tour_price': int(re.sub(r'[\D]+', '', p_tag)),
        'Tour_URL': a_tag.attrs['href']}
        result.append(temp)

# 투어 목록 상세 페이지
for tour in result:
    url = tour['Tour_URL']

    res = requests.get(url,
                headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Whale/4.32.315.22 Safari/537.36',
                        'cookie': 'v=1.0.313; _ga=GA1.1.762332180.1752736610; CookieConsent={stamp:%27smOAvwHrouD3ERr0LAClV08CPzvUWzHxlHpL7bgMN48vygQuEMsBgw==%27%2Cnecessary:true%2Cpreferences:true%2Cstatistics:true%2Cmarketing:true%2Cmethod:%27explicit%27%2Cver:1%2Cutc:1752736611021%2Cregion:%27kr%27}; _gcl_au=1.1.1437524738.1752736611; _fbp=fb.1.1752736613392.535065786467195256; vsd=%7B%22cc%22%3A%22KR%22%2C%22cn%22%3A%22South%20Korea%22%2C%22ci%22%3A114%2C%22cp%22%3A%22%2B82%22%2C%22c%22%3A%22Asia%22%2C%22cg%22%3A0%2C%22ri%22%3A7%2C%22ip%22%3A%22211.34.202.232%22%2C%22d%22%3A2%2C%22cur%22%3A%22KRW%22%7D; laravel_session=rNYT1LO549F7Tu2fLIYwNovHOxQpTQrXlLfBgk5i; hpp=8%2C7%2C0; list_location=%2Ftours%3Fcur%3Dkrw%7C%7C%2Ftours%3Ffilter%3Dall%26cur%3Dkrw; _ga_D6DBBH8PKF=GS2.1.s1753160001$o11$g1$t1753161456$j59$l0$h0; _uetsid=b56e8e40662611f0b28a21bd6cad6003; _uetvid=02ee75c062de11f098f641fe3c03548d; prf=%7B%22sd%22%3A%22%22%2C%22sf%22%3A1%2C%22ta%22%3A2%2C%22tc%22%3A0%2C%22tca%22%3A%22%22%2C%22td%22%3Afalse%2C%22up%22%3A%2220250722141738%22%7D; XSRF-TOKEN=%3D'
                })
    soup = BeautifulSoup(res.text, 'html.parser')

    route_tag = soup.select('div.tour__route-list-inner tr td')

    locations = []

    for route in route_tag:
        text = route.text.strip()

        if re.search(r'(Day|Start|End)', text):
            continue
        locations.append(text)
    if locations:
        locations = locations[1:] # 나라명 맨 앞이라 자름

    start_city = re.sub(r'\s*\(Day \d+\)', '', route_tag[2].text)
    end_city = re.sub(r'\s*\(Day \d+\)', '', route_tag[-1].text)

    Tour_style = soup.select('h4')[0].text
    Tour_type = soup.select('h4')[1].text

    tour['Tour_locations'] = locations
    tour['Tour_start'] = start_city
    tour['Tour_end'] = end_city
    tour['Tour_style'] = Tour_style
    tour['Tour_type'] = Tour_type
result
# Out:
# 현재 페이지: 1
# 13,897 African Safari Tours (Offered by Top Rated Tour Operators)
# 1페이지 투어 개수: 20
# 누적 투어 개수: 20
# 현재 페이지: 2
# 13,897 African Safari Tours (Offered by Top Rated Tour Operators) - Page 2 - Showing 21-40 of 13,897
# 2페이지 투어 개수: 20
# 누적 투어 개수: 40
# [{'Tour_ID': '72050',
#   'Tour_title': '4-Day Serengeti Luxury Trip & Four Seasons Safari Lodge',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3951824,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t72050',
#   'Tour_locations': ['Serengeti NP', 'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha (City)',
#   'Tour_style': 'Luxury+ tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '47292',
#   'Tour_title': '9-Day Tanzanian Grand Safari - Elephants to Flamingos',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 4711265,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t47292',
#   'Tour_locations': ['Tarangire NP',
#    'Lake Manyara NP',
#    'Ngorongoro Crater',
#    'Lake Natron',
#    'Serengeti NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '55857',
#   'Tour_title': '5-Day 4x4 Masai Mara to the Lake Edition Budget Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 1010012,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t55857',
#   'Tour_locations': ['Masai Mara NR', 'Lake Nakuru NP', 'Hell’s Gate NP'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (City)',
#   'Tour_style': 'Budget tour',
#   'Tour_type': 'Shared tour'},
#  {'Tour_ID': '36735',
#   'Tour_title': '10-Day Classic Zimbabwe Safari',
#   'Tour_country': 'Zimbabwe',
#   'Tour_price': 10369765,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t36735',
#   'Tour_locations': ['Victoria Falls',
#    'Hwange NP',
#    'Matusadona NP',
#    'Victoria Falls Airport (Victoria Falls)'],
#   'Tour_start': 'Victoria Falls Town',
#   'Tour_end': 'Victoria Falls Town',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '41315',
#   'Tour_title': '5-Day Tarangire, Ngorongoro & Manyara Perfect Trip',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 1826844,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t41315',
#   'Tour_locations': ['Arusha (City)',
#    'Tarangire NP',
#    'Ngorongoro Crater',
#    'Lake Manyara NP',
#    'Arusha (City)'],
#   'Tour_start': 'Moshi',
#   'Tour_end': 'Moshi',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '40001',
#   'Tour_title': '4-Day Zanzibar to Nyerere NP (Selous GR) Flying Package',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 1452653,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t40001',
#   'Tour_locations': ['Nyerere NP'],
#   'Tour_start': 'Zanzibar',
#   'Tour_end': 'Zanzibar',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '85188',
#   'Tour_title': '5-Day Manyara, Serengeti & Ngorongoro Crater',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3239948,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t85188',
#   'Tour_locations': ['Lake Manyara NP',
#    'Central Serengeti NP',
#    'Serengeti NP',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '13538',
#   'Tour_title': '12-Day Gorillas, Chimps & Wildlife Epic Safari',
#   'Tour_country': 'Uganda',
#   'Tour_price': 5323858,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t13538',
#   'Tour_locations': ['Murchison Falls NP',
#    'Kibale NP (Chimps)',
#    'Queen Elizabeth NP',
#    'Bwindi Impenetrable NP (Gorillas)',
#    'Mgahinga Gorilla NP (Gorillas)',
#    'Lake Mburo NP'],
#   'Tour_start': 'Entebbe',
#   'Tour_end': 'Entebbe (Entebbe)',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '61527',
#   'Tour_title': '6-Day Extraordinary to Witness the Great Migration',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 1452653,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t61527',
#   'Tour_locations': ['Tarangire NP',
#    'Central Serengeti NP',
#    'Northern Serengeti NP',
#    'Serengeti NP',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Budget tour',
#   'Tour_type': 'Shared tour'},
#  {'Tour_ID': '11621',
#   'Tour_title': '7-Day Journey of the Wildebeest - Luxury',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 5821669,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t11621',
#   'Tour_locations': ['Lake Manyara NP',
#    'Ngorongoro Crater',
#    'Central Serengeti NP',
#    'Serengeti NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '72814',
#   'Tour_title': '6-Day Ultimate Mid-Range Safari Adventure',
#   'Tour_country': 'Kenya',
#   'Tour_price': 2471791,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t72814',
#   'Tour_locations': ['Amboseli NP', 'Lake Nakuru NP', 'Masai Mara NR'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (Nairobi)',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '38192',
#   'Tour_title': '4-Day And Beyond Masai Mara Luxury Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 4167820,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t38192',
#   'Tour_locations': ['Masai Mara NR'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (City)',
#   'Tour_style': 'Luxury+ tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '33103',
#   'Tour_title': '7-Day Masai Mara Nakuru Amboseli Kenya Budget Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 1265557,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t33103',
#   'Tour_locations': ['Masai Mara NR',
#    'Lake Nakuru NP',
#    'Lake Naivasha (Naivasha)',
#    'Amboseli NP'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (City)',
#   'Tour_style': 'Budget tour',
#   'Tour_type': 'Shared tour'},
#  {'Tour_ID': '70129',
#   'Tour_title': '5-Day Serengeti Wildebeest Migration',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 2768406,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t70129',
#   'Tour_locations': ['Tarangire NP',
#    'Ngorongoro Crater',
#    'Northern Serengeti NP',
#    'Central Serengeti NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '93764',
#   'Tour_title': '4-Day Awesome Tour to Tarangire, Serengeti & Ngorongoro',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 2197993,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t93764',
#   'Tour_locations': ['Tarangire NP', 'Serengeti NP', 'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '81074',
#   'Tour_title': '9-Day Tropical Paradise & Wild Adventures in Zanzibar',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 4010295,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t81074',
#   'Tour_locations': ['Tarangire NP',
#    'Central Serengeti NP',
#    'Ngorongoro Crater',
#    'Lake Manyara NP',
#    'Zanzibar Stone Town (Zanzibar)',
#    'Zanzibar (Tanzania Beaches)'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Zanzibar (Zanzibar)',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '52188',
#   'Tour_title': '11-Day The Classics Tour Comfort',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 5203554,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t52188',
#   'Tour_locations': ['Tarangire NP',
#    'Lake Manyara NP',
#    'Ndutu (Southern Serengeti NP)',
#    'Serengeti NP',
#    'Pololeti GR (Greater Serengeti)',
#    'Ndutu (Southern Serengeti NP)',
#    'Ngorongoro Crater',
#    'Kilimanjaro Airport'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '27254',
#   'Tour_title': '7-Day Magical Kenya Luxury Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 6043339,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t27254',
#   'Tour_locations': ['Amboseli NP',
#    'Lake Naivasha (Naivasha)',
#    'Lake Nakuru NP',
#    'Masai Mara NR'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '31883',
#   'Tour_title': '6-Day Private Mara River Grossing Migration in Serengeti',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3194315,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t31883',
#   'Tour_locations': ['Central Serengeti NP',
#    'Northern Serengeti NP',
#    'Ngorongoro Crater',
#    'Kilimanjaro Airport'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '57603',
#   'Tour_title': '6-Day Beyond Luxury - 2 Nights Four Season Safari Lodge',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 5725429,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t57603',
#   'Tour_locations': ['Arusha (City)',
#    'Tarangire NP',
#    'Serengeti NP',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Moshi',
#   'Tour_end': 'Moshi',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '41005',
#   'Tour_title': '5-Day Great Migration at the Mara River Crossing',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3045247,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t41005',
#   'Tour_locations': ['Tarangire NP',
#    'Central Serengeti NP',
#    'Northern Serengeti NP',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '22453',
#   'Tour_title': '7-Day Tarangire, Lake Manyara & Serengeti Luxury Safari',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 14241655,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t22453',
#   'Tour_locations': ['Tarangire NP',
#    'Karatu District',
#    'Ngorongoro Crater',
#    'Central Serengeti NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha (City)',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '22476',
#   'Tour_title': '4-Day Lake Manyara, Serengeti & Ngorongoro Adventure',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 2737984,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t22476',
#   'Tour_locations': ['Lake Manyara NP',
#    'Serengeti NP',
#    'Ngorongoro Highlands',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '25249',
#   'Tour_title': '6-Day Majestic Tanzania - Mid-Range',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3692126,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t25249',
#   'Tour_locations': ['Tarangire NP',
#    'Lake Manyara NP',
#    'Serengeti NP',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '9480',
#   'Tour_title': '7-Day Northern Parks Budget Safari Tent',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3080932,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t9480',
#   'Tour_locations': ['Tarangire NP',
#    'Ngorongoro Crater',
#    'Serengeti NP',
#    'Lake Natron',
#    'Lake Manyara NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Budget tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '58039',
#   'Tour_title': '8-Day Private Mid-Range Serengeti Wildebeests Migration',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3954866,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t58039',
#   'Tour_locations': ['Tarangire NP',
#    'Serengeti NP',
#    'Ngorongoro Crater',
#    'Lake Manyara NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha (City)',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '66714',
#   'Tour_title': '6-Day Mid-Range Northern Circuit Wildlife Safari',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3186709,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t66714',
#   'Tour_locations': ['Tarangire NP',
#    'Central Serengeti NP',
#    'Northern Serengeti NP',
#    'Ngorongoro Crater',
#    'Lake Manyara NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '12166',
#   'Tour_title': '5-Day Fly in Sabi Sabi All Inclusive Safari',
#   'Tour_country': 'South Africa',
#   'Tour_price': 6813915,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t12166',
#   'Tour_locations': ['Sabi Sabi GR (Sabi Sands)'],
#   'Tour_start': 'Johannesburg',
#   'Tour_end': 'Johannesburg (Johannesburg)',
#   'Tour_style': 'Luxury+ tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '85347',
#   'Tour_title': '5-Day Masai Mara, Nakuru & Naivasha Budget Kenya Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 1140827,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t85347',
#   'Tour_locations': ['Masai Mara NR',
#    'Lake Nakuru NP',
#    'Lake Naivasha (Naivasha)'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (City)',
#   'Tour_style': 'Budget tour',
#   'Tour_type': 'Shared tour'},
#  {'Tour_ID': '10474',
#   'Tour_title': '6-Day Maasai Mara-Nakuru-Amboseli Kenya Budget Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 1105841,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t10474',
#   'Tour_locations': ['Masai Mara NR', 'Lake Nakuru NP', 'Amboseli NP'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (City)',
#   'Tour_style': 'Budget tour',
#   'Tour_type': 'Shared tour'},
#  {'Tour_ID': '51684',
#   'Tour_title': '6-Day The Ultimate Serengeti Experience',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3574590,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t51684',
#   'Tour_locations': ['Tarangire NP',
#    'Ngorongoro Crater',
#    'Serengeti NP',
#    'Northern Serengeti NP',
#    'Serengeti NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha (City)',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '65816',
#   'Tour_title': '8-Day Majestic Kenya Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 4715417,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t65816',
#   'Tour_locations': ['Amboseli NP',
#    'Lake Naivasha (Naivasha)',
#    'Lake Nakuru NP',
#    'Masai Mara NR'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (City)',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '44196',
#   'Tour_title': '8-Day Mara River Wildebeest Migration',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3635435,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t44196',
#   'Tour_locations': ['Tarangire NP',
#    'Central Serengeti NP',
#    'Northern Serengeti NP',
#    'Central Serengeti NP',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha (City)',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '63308',
#   'Tour_title': '5-Day Explore Great Migration Northern Serengeti',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 2806434,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t63308',
#   'Tour_locations': ['Tarangire NP',
#    'Central Serengeti NP',
#    'Northern Serengeti NP',
#    'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '46852',
#   'Tour_title': '14-Day Safari Adventure & Zanzibar Holiday - Bestseller',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 5386086,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t46852',
#   'Tour_locations': ['Tarangire NP',
#    'Lake Manyara NP',
#    'Serengeti NP',
#    'Ngorongoro Crater',
#    'Mto wa Mbu (Town)',
#    'Zanzibar Stone Town (Zanzibar)',
#    'Zanzibar (Tanzania Beaches)'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Zanzibar (Zanzibar)',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '77750',
#   'Tour_title': '7-Day Masai Mara/Nakuru/Naivasha/Amboseli Budget Safari',
#   'Tour_country': 'Kenya',
#   'Tour_price': 1355302,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t77750',
#   'Tour_locations': ['Masai Mara NR',
#    'Lake Nakuru NP',
#    'Hell’s Gate NP',
#    'Amboseli NP'],
#   'Tour_start': 'Nairobi',
#   'Tour_end': 'Nairobi (City)',
#   'Tour_style': 'Budget tour',
#   'Tour_type': 'Shared tour'},
#  {'Tour_ID': '94367',
#   'Tour_title': '3-Day Radisson Kruger Safari in Kruger National Park',
#   'Tour_country': 'South Africa',
#   'Tour_price': 977582,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t94367',
#   'Tour_locations': ['Kruger NP'],
#   'Tour_start': 'Johannesburg',
#   'Tour_end': 'Johannesburg',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Shared tour'},
#  {'Tour_ID': '86057',
#   'Tour_title': '4-Day Exclusive Safari from Zanzibar',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3287102,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t86057',
#   'Tour_locations': ['Tarangire NP', 'Ngorongoro Crater', 'Serengeti NP'],
#   'Tour_start': 'Zanzibar',
#   'Tour_end': 'Zanzibar',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '67517',
#   'Tour_title': '5-Day Luxury Romantic Honeymoon Safari',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 3387495,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t67517',
#   'Tour_locations': ['Tarangire NP', 'Serengeti NP', 'Ngorongoro Crater'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Luxury tour',
#   'Tour_type': 'Private tour'},
#  {'Tour_ID': '40448',
#   'Tour_title': '5-Day Budget-Private Serengeti, Ngorongoro, Tarangire',
#   'Tour_country': 'Tanzania',
#   'Tour_price': 2578268,
#   'Tour_URL': 'https://www.safaribookings.com/tours/t40448',
#   'Tour_locations': ['Tarangire NP',
#    'Central Serengeti NP',
#    'Ngorongoro Crater',
#    'Lake Manyara NP'],
#   'Tour_start': 'Arusha',
#   'Tour_end': 'Arusha',
#   'Tour_style': 'Mid-range tour',
#   'Tour_type': 'Private tour'}]

# %%
len(result)
# Out:
# 40
